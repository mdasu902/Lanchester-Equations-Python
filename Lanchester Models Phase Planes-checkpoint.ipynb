# %%
#Nump and Matplotlib will be used for Calcs and Plotting
import numpy as np
import matplotlib.pyplot as plt


#import the ODE solver from Scipy
from scipy.integrate import odeint


def fkode(p,R,k):
    dBdt = -p*R
    return dBdt

def fkode1(p,B,k):
    dRdt = -p*B
    return dRdt

# initial value
R0 = 1.2
B0 = 2.7 
# array of x values to seek y values for
xout = np.linspace(0, 140, 141)

# calculate ODE solutions
# k=1
yout1 = odeint(fkode, R0, xout, args=(1.0,))
# k=1.5
yout2 = odeint(fkode, R0, xout, args=(1.5,))
# k=2
yout3 = odeint(fkode, R0, xout, args=(2.0,))

# calculate ODE solutions
# k=1
yout4 = odeint(fkode1, B0, xout, args=(1.0,))
# k=1.5
yout5 = odeint(fkode1, B0, xout, args=(1.5,))
# k=2
yout6 = odeint(fkode1, B0, xout, args=(2.0,))


# plot results
# create a figure object
fig = plt.figure()
ax = fig.add_subplot(111)

# plot scaffolding
ax.set_xlim(0, 5)
ax.set_ylim(0, 3.5)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels([r"$0$", r"$1$",r"$2$", r"$3$", r"$4$"])
ax.set_xlabel(r"$t$")
ax.set_ylabel(r"$R$")


# plot numerical solution
ax.plot(xout, yout1, color="blue")
ax.plot(xout, yout6, color="green")
#ax.plot(xout, yout2, color="green")
#ax.plot(xout, yout3, color="darkred")

# display the plot
plt.show()
# Out:
# C:\Users\moham\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
# Anyone could predict this to be honest

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
from scipy.optimize import fsolve

def eqnXDotYDot(x, y): 
    dx = -10*y
    dy = -10*x
    return  ( dx, dy )

def func(variables):
    x, y = variables
    dx, dy = eqnXDotYDot(x, y)
    return (dx, dy)

def fixedPoints(X, Y):
    tolerance = 1e-5
    fPtX = []
    fPtY = []
    for i in range(nx):
        for j in range(ny):
            xFixedPoint, yFixedPoint = fsolve(func,(X[i,j],Y[i,j]))
            if all(np.isclose(eqnXDotYDot(xFixedPoint, yFixedPoint), [0.0, 0.0])) == True:
                if i == 0 and j == 0:
                    fPtX.append(xFixedPoint)
                    fPtY.append(yFixedPoint)
                    oldX, oldY = xFixedPoint, yFixedPoint
                    if abs(oldX - xFixedPoint)<tolerance and abs(oldY - yFixedPoint)<tolerance:
                        continue
                else:
                    fPtX.append(xFixedPoint)
                    fPtY.append(yFixedPoint)
                    oldX, oldY = xFixedPoint, yFixedPoint
    return (fPtX,fPtY)


# Grid of x, y points
nx, ny = 100, 100
minX, maxX = -1, 10
minY, maxY = -1, 10

x = np.linspace(minX, maxX, nx)
y = np.linspace(minY, maxY, ny)
X, Y = np.meshgrid(x, y)    

# field vector
dx, dy = eqnXDotYDot(X,Y)
# plot phase portrait with vector field
plt.figure()
plt.title("Phase Portrait")
ax = plt.gca()
#fig, ax = plt.subplots()
plt.minorticks_on()
minorLocatorX = AutoMinorLocator(2) # number of minor intervals per major inteval
minorLocatorY = AutoMinorLocator(2)
ax.xaxis.set_minor_locator(minorLocatorX) # add minor ticks on x axis
ax.yaxis.set_minor_locator(minorLocatorY) # add minor ticks on y axis

speed = np.sqrt(dx**2 + dy**2)
lw = speed  / speed.max()

ax.streamplot(x, y, dx, dy, linewidth=lw, density=1,color='b', arrowstyle='-',broken_streamlines=False)

ax.contour(X,Y,dx,levels=[0], linewidths=1, colors='r')
ax.contour(X,Y,dy,levels=[0], linewidths=1, colors='y')

fPtX,fPtY = fixedPoints(X, Y)
ax.scatter(fPtX,fPtY,s = 80, facecolors='none',edgecolors='green')

nx, ny = 15, 15
x = np.linspace(minX, maxX, nx)
y = np.linspace(minY, maxY, ny)
X, Y = np.meshgrid(x, y)  
dx, dy = eqnXDotYDot(X,Y) 
q = ax.quiver(X, Y, dx, dy,color='green',angles = 'uv', headlength=2,headaxislength=2)

ax.set_xlabel('$B(t)$')
ax.set_ylabel('$R(t)$')
ax.set_xlim(1.05*minX, 1.05*maxX)
ax.set_ylim(1.05*minY, 1.05*maxY)
ax.set_aspect('equal')
plt.grid(True)
#plt.savefig("pplane.png")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
from scipy.optimize import fsolve

def eqnXDotYDot(x, y): 
    dx = -10*y*x
    dy = -10*x*y
    return  ( dx, dy )

def func(variables):
    x, y = variables
    dx, dy = eqnXDotYDot(x, y)
    return (dx, dy)

def fixedPoints(X, Y):
    tolerance = 1e-5
    fPtX = []
    fPtY = []
    for i in range(nx):
        for j in range(ny):
            xFixedPoint, yFixedPoint = fsolve(func,(X[i,j],Y[i,j]))
            if all(np.isclose(eqnXDotYDot(xFixedPoint, yFixedPoint), [0.0, 0.0])) == True:
                if i == 0 and j == 0:
                    fPtX.append(xFixedPoint)
                    fPtY.append(yFixedPoint)
                    oldX, oldY = xFixedPoint, yFixedPoint
                    if abs(oldX - xFixedPoint)<tolerance and abs(oldY - yFixedPoint)<tolerance:
                        continue
                else:
                    fPtX.append(xFixedPoint)
                    fPtY.append(yFixedPoint)
                    oldX, oldY = xFixedPoint, yFixedPoint
    return (fPtX,fPtY)


# Grid of x, y points
nx, ny = 100, 100
minX, maxX = -1, 10
minY, maxY = -1, 10

x = np.linspace(minX, maxX, nx)
y = np.linspace(minY, maxY, ny)
X, Y = np.meshgrid(x, y)    

# field vector
dx, dy = eqnXDotYDot(X,Y)
# plot phase portrait with vector field
plt.figure()
plt.title("Phase Portrait")
ax = plt.gca()
#fig, ax = plt.subplots()
plt.minorticks_on()
minorLocatorX = AutoMinorLocator(2) # number of minor intervals per major inteval
minorLocatorY = AutoMinorLocator(2)
ax.xaxis.set_minor_locator(minorLocatorX) # add minor ticks on x axis
ax.yaxis.set_minor_locator(minorLocatorY) # add minor ticks on y axis

speed = np.sqrt(dx**2 + dy**2)
lw = speed  / speed.max()

ax.streamplot(x, y, dx, dy, linewidth=lw, density=1,color='b', arrowstyle='-',broken_streamlines=False)

ax.contour(X,Y,dx,levels=[0], linewidths=1, colors='r')
ax.contour(X,Y,dy,levels=[0], linewidths=1, colors='y')

fPtX,fPtY = fixedPoints(X, Y)
ax.scatter(fPtX,fPtY,s = 80, facecolors='none',edgecolors='green')

nx, ny = 15, 15
x = np.linspace(minX, maxX, nx)
y = np.linspace(minY, maxY, ny)
X, Y = np.meshgrid(x, y)  
dx, dy = eqnXDotYDot(X,Y) 
q = ax.quiver(X, Y, dx, dy,color='green',angles = 'uv', headlength=2,headaxislength=2)

ax.set_xlabel('$B(t)$')
ax.set_ylabel('$R(t)$')
ax.set_xlim(1.05*minX, 1.05*maxX)
ax.set_ylim(1.05*minY, 1.05*maxY)
ax.set_aspect('equal')
plt.grid(True)
#plt.savefig("pplane.png")
plt.tight_layout()
plt.show()

# %%
# define our ODE as a function
def penode(z,t):
    # separate vector y into constituant variable
    x,y = z
    # calculate a vector of derivatives
    dydt = [-1.5*y, -1.5*x]
    return dydt

# initial value vector
y0 = [0,  0]
y1 = [0, 0]
y2 = [0,0]
# array of x values to seek y values for
tout = np.linspace(0, 8, 201)



# calculate ODE solutions
soln1 = odeint(penode, y0, tout)
soln2 = odeint(penode, y1, tout)
soln3 = odeint(penode, y2, tout)



# plot results
fig = plt.figure()
ax = fig.add_subplot(111)

# plot scaffolding
ax.set_xlim(-0.5,5)
ax.set_ylim(-0.5, 5)
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data',0))


# set the aspect to be one-to-one
ax.set_aspect("equal")

# generate the positions of the arrows
# we use meshgid to produce a 2D array of positions
xq,yq = np.meshgrid(np.linspace(-1, 5, 17),np.linspace(-1,5, 17))

# calculate the directions of the arrows
# we can achieve this by putting the x and y positions
# into a list and passing them to our ODE function
uq, vq = penode([xq, yq],151)

# use the quiver function to plot the arrows
# the pivot argument tells Matplotlib to place the
# middle of the arrow at the (x,y) position
# other options are "tail" and "tip"
ax.quiver(xq,yq,uq,vq, pivot="middle", scale = 90,color="green")


# add the fixed point of the ODE
ax.plot([0],[0],marker="o", mfc="blue", mec="black")
#ax.plot([1],[2],marker="o", mfc="red", mec="red")

xsep=np.array([-1, 10])
ysep=xsep
ax.plot(xsep,ysep, linewidth=4,color="hotpink")

ax.legend(labels=['Directional Field Arrows', '(0,0)', 'Separatrix Line'], loc = 'upper right')

# add labels to the axes and a title to the plot
plt.xlabel('B(t)')
plt.ylabel('R(t)')
plt.title('Phase plane plot for Lanchesters Direct Fire Model',fontsize=22)

# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)

plt.savefig("Direct Fire Model.pdf", dpi=288, bbox_inches="tight")
plt.show()

# %%
# define our ODE as a function
def penode(z,t):
    # separate vector y into constituant variable
    x,y = z
    # calculate a vector of derivatives
    dydt = [-1.5*y*x, -1.5*x*y]
    return dydt

# initial value vector
y0 = [0,  0]
y1 = [0, 0]
y2 = [0,0]
# array of x values to seek y values for
tout = np.linspace(0, 8, 201)



# calculate ODE solutions
soln1 = odeint(penode, y0, tout)
soln2 = odeint(penode, y1, tout)
soln3 = odeint(penode, y2, tout)



# plot results
fig = plt.figure()
ax = fig.add_subplot(111)

# plot scaffolding
ax.set_xlim(-0.5,5)
ax.set_ylim(-0.5, 5)
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data',0))

# set the aspect to be one-to-one
ax.set_aspect("equal")

# generate the positions of the arrows
# we use meshgid to produce a 2D array of positions
xq,yq = np.meshgrid(np.linspace(-1, 5, 17),np.linspace(-1,5, 17))

# calculate the directions of the arrows
# we can achieve this by putting the x and y positions
# into a list and passing them to our ODE function
uq, vq = penode([xq, yq],151)

# use the quiver function to plot the arrows
# the pivot argument tells Matplotlib to place the
# middle of the arrow at the (x,y) position
# other options are "tail" and "tip"
ax.quiver(xq,yq,uq,vq, pivot="middle", scale = 90,color="green")


# add the fixed point of the ODE
ax.plot([0],[0],marker="o", mfc="blue", mec="black")
#ax.plot([1],[2],marker="o", mfc="red", mec="red")

xsep=np.array([-1, 10])
ysep=xsep
ax.plot(xsep,ysep, linewidth=4,color="hotpink")


ax.legend(labels=['Directional Field Arrows', '(0,0)', 'Separatrix Line'], loc = 'upper right')
# add labels to the axes and a title to the plot
plt.xlabel('B(t)')
plt.ylabel('R(t)')
plt.title('Phase plane plot for Lanchesters Indirect Fire Model', fontsize=22)

# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)

plt.savefig("Indirect Fire Model.pdf", dpi=288, bbox_inches="tight")
plt.show()

# %%
# define our ODE as a function
def penode(z,t):
    # separate vector y into constituant variable
    x,y = z
    # calculate a vector of derivatives
    dydt = [-1.5*y, -1.5*x*y]
    return dydt

# initial value vector
y0 = [0,  0]
y1 = [0, 0]
y2 = [0,0]
# array of x values to seek y values for
tout = np.linspace(0, 8, 201)



# calculate ODE solutions
soln1 = odeint(penode, y0, tout)
soln2 = odeint(penode, y1, tout)
soln3 = odeint(penode, y2, tout)



# plot results
fig = plt.figure()
ax = fig.add_subplot(111)

# plot scaffolding
ax.set_xlim(-0.5,5)
ax.set_ylim(-0.5, 5)
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data',0))

# set the aspect to be one-to-one
ax.set_aspect("equal")

# generate the positions of the arrows
# we use meshgid to produce a 2D array of positions
xq,yq = np.meshgrid(np.linspace(-1, 5, 17),np.linspace(-1,5, 17))

# calculate the directions of the arrows
# we can achieve this by putting the x and y positions
# into a list and passing them to our ODE function
uq, vq = penode([xq, yq],151)

# use the quiver function to plot the arrows
# the pivot argument tells Matplotlib to place the
# middle of the arrow at the (x,y) position
# other options are "tail" and "tip"
ax.quiver(xq,yq,uq,vq, pivot="middle", scale = 100,color="green")


# add legend to indicate which points correspond to which ODE solution

# add the fixed point of the ODE
ax.plot([0],[0],marker="o", mfc="blue", mec="black")
#ax.plot([1],[2],marker="o", mfc="red", mec="red")


xsep=np.linspace(-1, 10,100)
ysep=0.5*xsep**2
ax.plot(xsep,ysep, linewidth=4,color="hotpink")

# add labels to the axes and a title to the plot
plt.xlabel('B(t)')
plt.ylabel('R(t)')
plt.title('Phase plane plot for Lanchesters Mixed Fire Model',fontsize=22)

ax.legend(labels=['Directional Field Arrows', '(0,0)', 'Separatrix Line'], loc = 'upper right')

# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)

plt.savefig("Mixed Fire Model.pdf", dpi=288, bbox_inches="tight")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# Function definition
def R_t(t, R0, rho_R, rho_B, B0):
    return R0 * np.cosh(np.sqrt(rho_R * rho_B) * t) - (np.sqrt(rho_B/rho_R)) * B0 * np.sinh(np.sqrt(rho_R * rho_B) * t)
def B_t(t, R0, rho_R, rho_B, B0):
    return B0 * np.cosh(np.sqrt(rho_R * rho_B) * t) - (np.sqrt(rho_R/rho_B)) * R0 * np.sinh(np.sqrt(rho_R * rho_B) * t)

# Parameters
R0 = 100  # Initial value for R
rho_R = 0.05  # Value for rho_R
rho_B = 0.05  # Value for rho_B
B0 = 80  # Initial value for B

try:
    Rtmax = 1/(2*np.sqrt(rho_R*rho_B))*math.log(-(B0 + np.sqrt(rho_R/rho_B)*R0)/(B0 - np.sqrt(rho_R/rho_B)*R0))
    t_values = np.linspace(0, Rtmax, round(Rtmax)+1)
    days = list(range(round(Rtmax+1)))
    ax.set_xlim(0,Rtmax)
    print(Rtmax," -- days")

except ValueError:
    # Handle the case where the calculation for Rtmax raises a ValueError
    Btmax = 1/(2*np.sqrt(rho_R*rho_B))*math.log(-(R0 + np.sqrt(rho_B/rho_R)*B0)/(R0 - np.sqrt(rho_B/rho_R)*B0))
    t_values = np.linspace(0, Btmax, round(Btmax)+1)
    days = list(range(round(Btmax+1)))
    ax.set_xlim(0,Btmax)
    print(Btmax, " -- days ")

# Calculate R(t),B(t) values
R_values = R_t(t_values, R0, rho_R, rho_B, B0)
B_values = B_t(t_values, R0, rho_R, rho_B, B0)


# Plotting
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlim(0,Rtmax)
ax.set_ylim(0, 110)
plt.plot(t_values, R_values, label='R(t)')
plt.plot(t_values, B_values, label='B(t)')

# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)

plt.xlabel('Time (t)')
plt.ylabel('Population of Army R and B')
plt.title('Graph of R(t),B(t)', fontsize=22)
plt.legend()
plt.show()
# Out:
# 21.972245773362197  -- days

# %%
Rtmax = 1/(2*np.sqrt(rho_R*rho_B))*math.log(-(B0 + np.sqrt(rho_R/rho_B)*R0)/(B0 - np.sqrt(rho_R/rho_B)*R0))
Btmax = 1/(2*np.sqrt(rho_R*rho_B))*math.log(-(R0 + np.sqrt(rho_B/rho_R)*B0)/(R0 - np.sqrt(rho_B/rho_R)*B0))

# %%
import matplotlib.pyplot as plt

# Data
days = list(range(37))  # 0 to 35
american_troops = [73000, 71839, 69945, 69031, 66749, 66155, 65250, 64378, 62874, 62339, 61405, 60667,
                   59549, 59345, 59081, 58779, 58196, 57259, 56641, 54792, 55308, 54796, 54038, 53938,
                   53347, 53072, 52804, 52735, 52608, 52507, 52462, 52304, 52155, 52155, 52155, 52140, 52140]

japanese_troops = [21500, None, None, None, None, None, None, None, None, None, None, None, None, None, None,
                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None,
                   None, None, None, 0]

fig = plt.figure()

# Plotting
plt.scatter(days, american_troops, label='American Troops', marker='o')
#plt.plot(days, japanese_troops, label='Japanese Troops', marker='o')

# Adding labels and title
plt.xlabel('Days')
plt.ylabel('Number of Troops')
plt.title('American vs Japanese Troops over Time')

plt.scatter([0, 35], [japanese_troops[0], japanese_troops[-1]], label='Japanese Troops', marker='o', color='red')
# Adding legend
plt.legend()

# Display the plot
fig.set_figwidth(15)
fig.set_figheight(10)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# Function definition
def R_t(t, R0, rho_R, rho_B, B0):
    return R0 * np.cosh(np.sqrt(rho_R * rho_B) * t) - (np.sqrt(rho_B/rho_R)) * B0 * np.sinh(np.sqrt(rho_R * rho_B) * t)
def B_t(t, R0, rho_R, rho_B, B0):
    return B0 * np.cosh(np.sqrt(rho_R * rho_B) * t) - (np.sqrt(rho_R/rho_B)) * R0 * np.sinh(np.sqrt(rho_R * rho_B) * t)

# Parameters
R0 = 73000  # Initial value for R
rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
B0 = 21500  # Initial value for B


fig = plt.figure()
ax = fig.add_subplot(111)


try:
    Rtmax = 1/(2*np.sqrt(rho_R*rho_B))*math.log(-(B0 + np.sqrt(rho_R/rho_B)*R0)/(B0 - np.sqrt(rho_R/rho_B)*R0))
    t_values = np.linspace(0, Rtmax, round(Rtmax)+1)
    R_values = R_t(t_values, R0, rho_R, rho_B, B0)
    B_values = B_t(t_values, R0, rho_R, rho_B, B0)
    days = list(range(round(Rtmax+1)))
    ax.set_xlim(0,Rtmax)
    print(Rtmax," -- days")
    plt.text(Rtmax-5, 1000, f'Time: {Rtmax:.2f} days', verticalalignment='bottom', horizontalalignment='right')
    plt.text(Rtmax-5, R_values[-1]+10000, f'Survived : USA = {R_values[-1]:.0f}, Japan = 0', verticalalignment='bottom', horizontalalignment='right', color = 'red')
    plt.text(Rtmax-5, 1000, f'Time: {Rtmax:.2f} days', verticalalignment='bottom', horizontalalignment='right', color = 'red')


except ValueError:
    # Handle the case where the calculation for Rtmax raises a ValueError
    Btmax = 1/(2*np.sqrt(rho_R*rho_B))*math.log(-(R0 + np.sqrt(rho_B/rho_R)*B0)/(R0 - np.sqrt(rho_B/rho_R)*B0))
    t_values = np.linspace(0, Btmax, round(Btmax)+1)
    R_values = R_t(t_values, R0, rho_R, rho_B, B0)
    B_values = B_t(t_values, R0, rho_R, rho_B, B0)
    days = list(range(round(Btmax+1)))
    ax.set_xlim(0,Btmax)
    print(Btmax, " -- days ")
    plt.text(Btmax-5, B_values[-1]+10000, f'Survived : USA = 0, Japan = {B_values[-1]:.0f}', verticalalignment='bottom', horizontalalignment='right', color = 'blue')
    plt.text(Btmax-5, 1000, f'Time: {Btmax:.2f} days', verticalalignment='bottom', horizontalalignment='right', color = 'blue')






print(B_values)
days = list(range(36))  # 0 to 35

american_troops = [73000, 71839, 69945, 69031, 66749, 66155, 65250, 64378, 62874, 62339, 61405, 60667,
                   59549, 59345, 59081, 58779, 58196, 57259, 56641, 54792, 55308, 54796, 54038, 53938,
                   53347, 53072, 52804, 52735, 52608, 52507, 52462, 52304, 52155, 52155, 52155, 52140]

japanese_troops = [21500, None, None, None, None, None, None, None, None, None, None, None, None, None, None,
                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None,
                   None, None,None ,None,0]




# Plotting
ax.set_xlim(0,Rtmax)
ax.set_ylim(0, 75000)
plt.plot(t_values, R_values, label='R(t)')
plt.plot(t_values, B_values, label='B(t)')
plt.scatter(days, american_troops, label='American Troops', marker='o')
#plt.scatter([0, 35], [japanese_troops[0], japanese_troops[-1]], label='Japanese Troops', marker='o', color='red')
plt.scatter(days, B_values, label='Japanese Troops', marker='o')



# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)

plt.xlabel('Time (t)', fontsize = 15)
plt.ylabel('Population of Army R and B', fontsize = 15)
plt.title('America Vs Japan Iwo Jima', fontsize = 22)
plt.legend()
plt.show()
# Out:
# 34.99998523903505  -- days
# [21500. 20745. 20004. 19274. 18557. 17850. 17155. 16470. 15795. 15130.
#  14475. 13828. 13190. 12559. 11937. 11322. 10713. 10112.  9516.  8927.
#   8342.  7763.  7189.  6619.  6054.  5491.  4933.  4377.  3824.  3273.
#   2725.  2178.  1632.  1088.   544.     0.]

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# Function definition
def R_t(t, R0, rho_R, rho_B, B0):
    return R0 * np.cosh(np.sqrt(rho_R * rho_B) * t) - (np.sqrt(rho_B/rho_R)) * B0 * np.sinh(np.sqrt(rho_R * rho_B) * t)
def B_t(t, R0, rho_R, rho_B, B0):
    return B0 * np.cosh(np.sqrt(rho_R * rho_B) * t) - (np.sqrt(rho_R/rho_B)) * R0 * np.sinh(np.sqrt(rho_R * rho_B) * t)

# Parameters

R0 = 73000             # Initial value for R
rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
B0 = 32720             # Initial value for B


fig = plt.figure()
ax = fig.add_subplot(111)


try:
    Rtmax = 1/(2*np.sqrt(rho_R*rho_B))*math.log(-(B0 + np.sqrt(rho_R/rho_B)*R0)/(B0 - np.sqrt(rho_R/rho_B)*R0))
    t_values = np.linspace(0, Rtmax, round(Rtmax)+1)
    R_values = R_t(t_values, R0, rho_R, rho_B, B0)
    B_values = B_t(t_values, R0, rho_R, rho_B, B0)
    days = list(range(round(Rtmax+1)))
    ax.set_xlim(0,Rtmax)
    print(Rtmax," -- days")
    plt.text(Rtmax-5, 1000, f'Time: {Rtmax:.2f} days', verticalalignment='bottom', horizontalalignment='right')
    plt.text(Rtmax-5, R_values[-1]+10000, f'Survived : USA = {R_values[-1]:.0f}, Japan = 0', verticalalignment='bottom', horizontalalignment='right', color = 'red')
    plt.text(Rtmax-5, 1000, f'Time: {Rtmax:.2f} days', verticalalignment='bottom', horizontalalignment='right', color = 'red')


except ValueError:
    # Handle the case where the calculation for Rtmax raises a ValueError
    Btmax = 1/(2*np.sqrt(rho_R*rho_B))*math.log(-(R0 + np.sqrt(rho_B/rho_R)*B0)/(R0 - np.sqrt(rho_B/rho_R)*B0))
    t_values = np.linspace(0, Btmax, round(Btmax)+1)
    R_values = R_t(t_values, R0, rho_R, rho_B, B0)
    B_values = B_t(t_values, R0, rho_R, rho_B, B0)
    days = list(range(round(Btmax+1)))
    ax.set_xlim(0,Btmax)
    print(Btmax, " -- days ")
    plt.text(Btmax-5, B_values[-1]+10000, f'Survived : USA = 0, Japan = {B_values[-1]:.0f}', verticalalignment='bottom', horizontalalignment='right', color = 'blue')
    plt.text(Btmax-5, 1000, f'Time: {Btmax:.2f} days', verticalalignment='bottom', horizontalalignment='right', color = 'blue')







# Calculate R(t),B(t) values
#R_values = R_t(t_values, R0, rho_R, rho_B, B0)
#B_values = B_t(t_values, R0, rho_R, rho_B, B0)

print(B_values[-1])

american_troops = [73000, 71839, 69945, 69031, 66749, 66155, 65250, 64378, 62874, 62339, 61405, 60667,
                   59549, 59345, 59081, 58779, 58196, 57259, 56641, 54792, 55308, 54796, 54038, 53938,
                   53347, 53072, 52804, 52735, 52608, 52507, 52462, 52304, 52155, 52155, 52155, 52140]

japanese_troops = [21500, None, None, None, None, None, None, None, None, None, None, None, None, None, None,
                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None,
                   None, None,None ,None,0]




# Plotting
plt.yticks([0,R0,B0])
ax.set_ylim(0, 75000)
#plt.plot(t_values, R_values, label='R(t)')
#plt.plot(t_values, B_values, label='B(t)')
plt.plot(days, R_values, label='American Troops')
plt.plot(days, B_values, label='Japanese Troops')
# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)

plt.xlabel('Time (t)', fontsize = 15)
plt.ylabel('Population of Army R and B', fontsize = 15)
plt.title('Graph of R(t),B(t)', fontsize = 22)
plt.legend()
plt.show()
# Out:
# 69.75826433921311  -- days
# 11267.018379776171

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# Function definition
def R_t(t, R0, rho_R, rho_B, B0):
    return R0 * np.cosh(np.sqrt(rho_R * rho_B) * t) - (np.sqrt(rho_B/rho_R)) * B0 * np.sinh(np.sqrt(rho_R * rho_B) * t)
def B_t(t, R0, rho_R, rho_B, B0):
    return B0 * np.cosh(np.sqrt(rho_R * rho_B) * t) - (np.sqrt(rho_R/rho_B)) * R0 * np.sinh(np.sqrt(rho_R * rho_B) * t)

# Parameters

R0 = 51092      # Initial value for R
rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
B0 = 21500             # Initial value for B


fig = plt.figure()
ax = fig.add_subplot(111)


try:
    Rtmax = 1/(2*np.sqrt(rho_R*rho_B))*math.log(-(B0 + np.sqrt(rho_R/rho_B)*R0)/(B0 - np.sqrt(rho_R/rho_B)*R0))
    t_values = np.linspace(0, Rtmax, round(Rtmax)+1)
    R_values = R_t(t_values, R0, rho_R, rho_B, B0)
    B_values = B_t(t_values, R0, rho_R, rho_B, B0)
    days = list(range(round(Rtmax+1)))
    ax.set_xlim(0,Rtmax)
    print(Rtmax," -- days")
    plt.text(Rtmax-5, 1000, f'Time: {Rtmax:.2f} days', verticalalignment='bottom', horizontalalignment='right')
    plt.text(Rtmax-5, R_values[-1]+10000, f'Survived : USA = {R_values[-1]:.0f}, Japan = 0', verticalalignment='bottom', horizontalalignment='right', color = 'red')
    plt.text(Rtmax-5, 1000, f'Time: {Rtmax:.2f} days', verticalalignment='bottom', horizontalalignment='right', color = 'red')


except ValueError:
    # Handle the case where the calculation for Rtmax raises a ValueError
    Btmax = 1/(2*np.sqrt(rho_R*rho_B))*math.log(-(R0 + np.sqrt(rho_B/rho_R)*B0)/(R0 - np.sqrt(rho_B/rho_R)*B0))
    t_values = np.linspace(0, Btmax, round(Btmax)+1)
    R_values = R_t(t_values, R0, rho_R, rho_B, B0)
    B_values = B_t(t_values, R0, rho_R, rho_B, B0)
    days = list(range(round(Btmax+1)))
    ax.set_xlim(0,Btmax)
    print(Btmax, " -- days ")
    plt.text(Btmax-5, B_values[-1]+10000, f'Survived : USA = 0, Japan = {B_values[-1]:.0f}', verticalalignment='bottom', horizontalalignment='right', color = 'blue')
    plt.text(Btmax-5, 1000, f'Time: {Btmax:.2f} days', verticalalignment='bottom', horizontalalignment='right', color = 'blue')





# Calculate R(t),B(t) values
#R_values = R_t(t_values, R0, rho_R, rho_B, B0)
#B_values = B_t(t_values, R0, rho_R, rho_B, B0)

print(B_values[-1])

american_troops = [73000, 71839, 69945, 69031, 66749, 66155, 65250, 64378, 62874, 62339, 61405, 60667,
                   59549, 59345, 59081, 58779, 58196, 57259, 56641, 54792, 55308, 54796, 54038, 53938,
                   53347, 53072, 52804, 52735, 52608, 52507, 52462, 52304, 52155, 52155, 52155, 52140]

japanese_troops = [21500, None, None, None, None, None, None, None, None, None, None, None, None, None, None,
                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None,
                   None, None,None ,None,0]




# Plotting
plt.yticks([0,R0,B0])
ax.set_ylim(0, 75000)
#plt.plot(t_values, R_values, label='R(t)')
#plt.plot(t_values, B_values, label='B(t)')
plt.plot(days, R_values, label='American Troops', color = 'blue')
plt.plot(days, B_values, label='Japanese Troops', color = 'red')
# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)

plt.xlabel('Time (t)', fontsize = 15)
plt.ylabel('Population of Army R and B', fontsize = 15)
plt.title('Graph of R(t),B(t)', fontsize = 22)
plt.legend()
plt.show()
# Out:
# 258.9682061741259  -- days
# 70.33357808832079

# %%
# stochastic model attempt

R0 = 73000  # Initial value for R
rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
B0 = 21500             # Initial value for B

# %%
# rough beginnings for stochastic model
# small numbers first for testing purposes to see what an actual stochastic model looks like


import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

n = 10000
R = np.zeros(n)
R[0] = 73


B = np.zeros(n)
B[0] = 32


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier
x = random.uniform(0, 1) 

for i in range(1, n-1):
    if R[i-1] <= 0 or B[i-1] <= 0:
        break
    p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
    x = random.uniform(0, 1) # should change everytime too
    if x <= p:
        R[i] = R[i-1] - 1
        if i < n:
            B[i] = B[i-1]
    else:
        R[i] = R[i-1]
        if i < n:
            B[i] = B[i-1] - 1

fig = plt.figure()
ax = fig.add_subplot(111)
t = np.arange(0,n)


plt.plot(t,R, label="R(t)")
plt.plot(t,B, label = "B(t)")

# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)
ax.set_ylim(0, 100)
ax.set_xlim(0, i)

plt.show()

print("Random x:", x)
print("Final p:", p)
print("Final B:", B[i-1])
print("Final R:", R[i-1])
# Out:
# Random x: 0.001742356710040971
# Final p: 0.9883324874319183
# Final B: 15.0
# Final R: 0.0

# %%
# rough beginnings for stochastic model
# using my actual values


import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

n = 100000  # we don't really know how big the vector needs to be so 1 million should suffice
R = np.zeros(n)
R[0] = 73000

# should be 21.5 + 73
B = np.zeros(n)
B[0] = 21500


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier
x = random.uniform(0, 1) 

for i in range(1, n-1):
    if R[i-1] <= 0 or B[i-1] <= 0:   # stops when the army reaches 0
        break
    p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
    x = random.uniform(0, 1) # should this be changing everytime too
    if x <= p:
        R[i] = R[i-1] - 1
        if i < n:
            B[i] = B[i-1]
    else:
        R[i] = R[i-1]
        if i < n:
            B[i] = B[i-1] - 1

fig = plt.figure()
ax = fig.add_subplot(111)
t = np.arange(0,n)
t0 = np.arange(0,n)


plt.plot(t,R, label="R(t)")
plt.plot(t,B, label = "B(t)")

# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)
ax.set_ylim(0, 75000)
ax.set_xlim(0, i)

plt.show()

print("Random x:", x)
print("Final p:", p)
print("Final B:", B[i-1])
print("Final R:", R[i-1])
# Out:
# Random x: 0.46668996303230204
# Final p: 0.00010880379061049479
# Final B: 0.0
# Final R: 51897.0

# %%
# rough beginnings for stochastic model

import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

n = 1000000
R = np.zeros(n)
R[0] = 73000


B = np.zeros(n)
B[0] = 32718


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier
#x = random.uniform(0, 1) 

for i in range(1, n-1):
    if R[i-1] <= 0 or B[i-1] <= 0:
        break
    p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
    x = random.uniform(0, 1) # should this be changing everytime too
    if x <= p:
        R[i] = R[i-1] - 1
        if i < n:
            B[i] = B[i-1]
    else:
        R[i] = R[i-1]
        if i < n:
            B[i] = B[i-1] - 1

fig = plt.figure()
ax = fig.add_subplot(111)
t = np.arange(0,n) # casualties 


plt.plot(t,R, label="R(t)")
plt.plot(t,B, label = "B(t)")

# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)
ax.set_ylim(0, 75000)
ax.set_xlim(0, i)

plt.show()

print("Random x:", x)
print("Final p:", p)
print("Final B:", B[i-1])
print("Final R:", R[i-1])
# Out:
# Random x: 0.23390951166369245
# Final p: 0.9999837753450518
# Final B: 10914.0
# Final R: 0.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

simulation = 10000
n = 1000000
R_win = 0
B_win = 0


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier
#x = random.uniform(0, 1) 

for i in range(simulation):
    R = np.zeros(n)
    R[0] = 51091
    B = np.zeros(n)
    B[0] = 21500
    
    
    for i in range(1, n-1):
        
        if R[i-1] <= 0 or B[i-1] <= 0:
            break
        p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
        x = random.uniform(0, 1) #  changing everytime too
        
        
        if x <= p:
            R[i] = R[i-1] - 1
            if i < n:
                B[i] = B[i-1]
        
        else:
            R[i] = R[i-1]
            if i < n:
                B[i] = B[i-1] - 1
                
    if R[i-1] > B[i-1]:
        R_win += 1
    elif B[i-1] > R[i-1]:
        B_win += 1
        
        
print("America Victories:", R_win)
print("Japanese Victories:", B_win)
# Out:
# America Victories: 5025
# Japanese Victories: 4975

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

simulation = 100
n = 1000000
R_win = 0
B_win = 0


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier

for i in range(simulation):
    R = np.zeros(n)
    R[0] = 73000
    B = np.zeros(n)
    B[0] = 30800
    
    
    for i in range(1, n-1):
        
        if R[i-1] <= 0 or B[i-1] <= 0:
            break
        p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
        x = random.uniform(0, 1) #  changing everytime too
        
        
        if x <= p:
            R[i] = R[i-1] - 1
            if i < n:
                B[i] = B[i-1]
        
        else:
            R[i] = R[i-1]
            if i < n:
                B[i] = B[i-1] - 1
                
    if R[i-1] > B[i-1]:
        R_win += 1
    elif B[i-1] > R[i-1]:
        B_win += 1
        
        
print("America Victories:", R_win)
print("Japanese Victories:", B_win)
# Out:
# America Victories: 28
# Japanese Victories: 72

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

simulation = 1000
n = 1000000
R_win = 0
B_win = 0


rho_R = 1  # Value for rho_R
rho_B = 1  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier

for i in range(simulation):
    R = np.zeros(n)
    R[0] = 1000
    B = np.zeros(n)
    B[0] = 1000
    
    
    for i in range(1, n-1):
        
        if R[i-1] <= 0 or B[i-1] <= 0:
            break
        p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
        x = random.uniform(0, 1) #  changing everytime too
        
        
        if x <= p:
            R[i] = R[i-1] - 1
            if i < n:
                B[i] = B[i-1]
        
        else:
            R[i] = R[i-1]
            if i < n:
                B[i] = B[i-1] - 1
                
    if R[i-1] > B[i-1]:
        R_win += 1
    elif B[i-1] > R[i-1]:
        B_win += 1
        
        
print("America Victories:", R_win)
print("Japanese Victories:", B_win)
# Out:
# America Victories: 497
# Japanese Victories: 503

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

simulation = 1000
n = 1000000
R_win = 0
B_win = 0


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier
#x = random.uniform(0, 1) 

for i in range(simulation):
    R = np.zeros(n)
    R[0] = 73000
    B = np.zeros(n)
    B[0] = 30718
    
    
    for i in range(1, n-1):
        
        if R[i-1] <= 0 or B[i-1] <= 0:
            break
        p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
        x = random.uniform(0, 1) #  changing everytime too
        
        
        if x <= p:
            R[i] = R[i-1] - 1
            if i < n:
                B[i] = B[i-1]
        
        else:
            R[i] = R[i-1]
            if i < n:
                B[i] = B[i-1] - 1
                
    if R[i-1] > B[i-1]:
        R_win += 1
    elif B[i-1] > R[i-1]:
        B_win += 1
        
        
print("America Victories:", R_win)
print("Japanese Victories:", B_win)
# Out:
# America Victories: 501
# Japanese Victories: 499

# %%
# rough beginnings for stochastic model

import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

n = 1000000
R = np.zeros(n)
R[0] = 73000


B = np.zeros(n)
B[0] = 32718


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier
#x = random.uniform(0, 1) 

for i in range(1, n-1):
    if R[i-1] <= 0 or B[i-1] <= 0:
        break
    p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
    x = random.uniform(0, 1) # should this be changing everytime too
    if x <= p:
        R[i] = R[i-1] - 1
        if i < n:
            B[i] = B[i-1]
    else:
        R[i] = R[i-1]
        if i < n:
            B[i] = B[i-1] - 1

fig = plt.figure()
ax = fig.add_subplot(111)
t = np.arange(0,n) # casualties 


#plt.plot(t,R, label="R(t)")
plt.plot(B,R, label = "B(t)")

# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)
ax.set_ylim(0, 75000)
ax.set_xlim(0, 40000)

plt.show()

print("Random x:", x)
print("Final p:", p)
print("Final B:", B[i-1])
print("Final R:", R[i-1])
# Out:
# Random x: 0.5641965264119829
# Final p: 0.9999837066735421
# Final B: 10868.0
# Final R: 0.0
