# %%
# rough beginnings for stochastic model
# small numbers first for testing purposes to see what an actual stochastic model looks like


import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

n = 10000
R = np.zeros(n)
R[0] = 73


B = np.zeros(n)
B[0] = 32


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier
x = random.uniform(0, 1) 

for i in range(1, n-1):
    if R[i-1] <= 0 or B[i-1] <= 0:
        break
    p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
    x = random.uniform(0, 1) # should change everytime too
    if x <= p:
        R[i] = R[i-1] - 1
        if i < n:
            B[i] = B[i-1]
    else:
        R[i] = R[i-1]
        if i < n:
            B[i] = B[i-1] - 1

fig = plt.figure()
ax = fig.add_subplot(111)
t = np.arange(0,n)


plt.plot(t,R, label="R(t)")
plt.plot(t,B, label = "B(t)")

# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)
ax.set_ylim(0, 100)
ax.set_xlim(0, i)

plt.show()

print("Random x:", x)
print("Final p:", p)
print("Final B:", B[i-1])
print("Final R:", R[i-1])
# Out:
# Random x: 0.7433962598926698
# Final p: 0.9186622180917686
# Final B: 2.0
# Final R: 0.0

# %%
# rough beginnings for stochastic model
# using my actual values


import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

n = 100000  # we don't really know how big the vector needs to be so 1 million should suffice
R = np.zeros(n)
R[0] = 73000

# should be 21.5 + 73
B = np.zeros(n)
B[0] = 21500


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier
x = random.uniform(0, 1) 

for i in range(1, n-1):
    if R[i-1] <= 0 or B[i-1] <= 0:   # stops when the army reaches 0
        break
    p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
    x = random.uniform(0, 1) # should this be changing everytime too
    if x <= p:
        R[i] = R[i-1] - 1
        if i < n:
            B[i] = B[i-1]
    else:
        R[i] = R[i-1]
        if i < n:
            B[i] = B[i-1] - 1

fig = plt.figure()
ax = fig.add_subplot(111)
t = np.arange(0,n)
t0 = np.arange(0,n)


plt.plot(t,R, label="R(t)")
plt.plot(t,B, label = "B(t)")

# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)
ax.set_ylim(0, 75000)
ax.set_xlim(0, i)

plt.show()

print("Random x:", x)
print("Final p:", p)
print("Final B:", B[i-1])
print("Final R:", R[i-1])
# Out:
# Random x: 0.29392970895072257
# Final p: 0.00010801505041491763
# Final B: 0.0
# Final R: 52276.0

# %%
# rough beginnings for stochastic model

import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

n = 1000000
R = np.zeros(n)
R[0] = 73000


B = np.zeros(n)
B[0] = 32718


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier
#x = random.uniform(0, 1) 

for i in range(1, n-1):
    if R[i-1] <= 0 or B[i-1] <= 0:
        break
    p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
    x = random.uniform(0, 1) # should this be changing everytime too
    if x <= p:
        R[i] = R[i-1] - 1
        if i < n:
            B[i] = B[i-1]
    else:
        R[i] = R[i-1]
        if i < n:
            B[i] = B[i-1] - 1

fig = plt.figure()
ax = fig.add_subplot(111)
t = np.arange(0,n) # casualties 


plt.plot(t,R, label="R(t)")
plt.plot(t,B, label = "B(t)")

# display the plot
fig.set_figwidth(15)
fig.set_figheight(10)
ax.set_ylim(0, 75000)
ax.set_xlim(0, i)

plt.show()

print("Random x:", x)
print("Final p:", p)
print("Final B:", B[i-1])
print("Final R:", R[i-1])
# Out:
# Random x: 0.15836839173644646
# Final p: 0.9999847084586063
# Final B: 11580.0
# Final R: 0.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

simulation = 100
n = 1000000
R_win = 0
B_win = 0


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier
#x = random.uniform(0, 1) 

for i in range(simulation):
    R = np.zeros(n)
    R[0] = 51091
    B = np.zeros(n)
    B[0] = 21500
    
    
    for i in range(1, n-1):
        
        if R[i-1] <= 0 or B[i-1] <= 0:
            break
        p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
        x = random.uniform(0, 1) #  changing everytime too
        
        
        if x <= p:
            R[i] = R[i-1] - 1
            if i < n:
                B[i] = B[i-1]
        
        else:
            R[i] = R[i-1]
            if i < n:
                B[i] = B[i-1] - 1
                
    if R[i-1] > B[i-1]:
        R_win += 1
    elif B[i-1] > R[i-1]:
        B_win += 1
        
        
print("America Victories:", R_win)
print("Japanese Victories:", B_win)
# Out:
# America Victories: 46
# Japanese Victories: 54

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

simulation = 100
n = 1000000
R_win = 0
B_win = 0


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier

for i in range(simulation):
    R = np.zeros(n)
    R[0] = 73000
    B = np.zeros(n)
    B[0] = 30800
    
    
    for i in range(1, n-1):
        
        if R[i-1] <= 0 or B[i-1] <= 0:
            break
        p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
        x = random.uniform(0, 1) #  changing everytime too
        
        
        if x <= p:
            R[i] = R[i-1] - 1
            if i < n:
                B[i] = B[i-1]
        
        else:
            R[i] = R[i-1]
            if i < n:
                B[i] = B[i-1] - 1
                
    if R[i-1] > B[i-1]:
        R_win += 1
    elif B[i-1] > R[i-1]:
        B_win += 1
        
        
print("America Victories:", R_win)
print("Japanese Victories:", B_win)
# Out:
# America Victories: 21
# Japanese Victories: 79

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

simulation = 1000
n = 1000000
R_win = 0
B_win = 0


rho_R = 1  # Value for rho_R
rho_B = 1  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier

for i in range(simulation):
    R = np.zeros(n)
    R[0] = 1000
    B = np.zeros(n)
    B[0] = 1000
    
    
    for i in range(1, n-1):
        
        if R[i-1] <= 0 or B[i-1] <= 0:
            break
        p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
        x = random.uniform(0, 1) #  changing everytime too
        
        
        if x <= p:
            R[i] = R[i-1] - 1
            if i < n:
                B[i] = B[i-1]
        
        else:
            R[i] = R[i-1]
            if i < n:
                B[i] = B[i-1] - 1
                
    if R[i-1] > B[i-1]:
        R_win += 1
    elif B[i-1] > R[i-1]:
        B_win += 1
        
        
print("America Victories:", R_win)
print("Japanese Victories:", B_win)

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
np.set_printoptions(suppress=True, precision=0)

simulation = 1000
n = 1000000
R_win = 0
B_win = 0


rho_R = 0.01042511998  # Value for rho_R
rho_B = 0.05887278716  # Value for rho_B
p = (rho_B * B[0]) / (rho_B * B[0] + rho_R * R[0]) # probability for Red team to lose a soldier
#x = random.uniform(0, 1) 

for i in range(simulation):
    R = np.zeros(n)
    R[0] = 73000
    B = np.zeros(n)
    B[0] = 30718
    
    
    for i in range(1, n-1):
        
        if R[i-1] <= 0 or B[i-1] <= 0:
            break
        p = (rho_B * B[i-1]) / (rho_B * B[i-1] + rho_R * R[i-1])
        x = random.uniform(0, 1) #  changing everytime too
        
        
        if x <= p:
            R[i] = R[i-1] - 1
            if i < n:
                B[i] = B[i-1]
        
        else:
            R[i] = R[i-1]
            if i < n:
                B[i] = B[i-1] - 1
                
    if R[i-1] > B[i-1]:
        R_win += 1
    elif B[i-1] > R[i-1]:
        B_win += 1
        
        
print("America Victories:", R_win)
print("Japanese Victories:", B_win)
